# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json

# %%
url = "https://www.bbc.com/sport/football/premier-league/top-scorers"

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="b-reith-sans-font" lang="en-GB">
# <head>
# <script>window.Morph = {}</script>
# <script type="text/javascript">Morph.markPerformance = function(label) { if(window.performance && window.performance.mark) { window.performance.mark(label); } }; Morph.versions = {}; Morph.modules = {}; Morph.config = { cdn: "m.files.bbci.co.uk", pushEnv: "live" }; Morph.styles = {}; Morph.styleSrc = []; Morph.toInit = {bundles: [], registers: [], payloads: []};   Morph.initStyles = function() { if (!Morph.enhanced) { var eles = Array.prototype.slice.call(document.getElementsByTagName('noscript')); for (var i = 0, len = eles.length; i<len; i++) { if (eles[i].className === 'morph-core-style') { document.write(eles[i].innerText); eles[i].parentNode.removeChild(eles[i]); } } return; } for (var j = 0, jLen = Morph.styleSrc.length; j<jLen; j++) { document.write(Morph.styleSrc[j]); } Morph.styleSrc = []; };</script>
# ...

# %%
[x.text for x in soup.find("tbody", "gel-long-primer").find_all("td", "gs-o-table__cell gs-o-table__cell--right gs-u-display-none gs-u-display-table-cell@m")]
#soup.find("tbody","gel-long-primer").find("tr").find("td", "gs-o-table__cell gs-o-table__cell--left").find("div").find("div","sp-c-top-scorers__player-name gel-long-primer-bold").find("span", "sp-c-abbreviation-switcher").find("span", "gs-u-vh gs-u-display-inherit@m").text
# Out:
# ['0.68',
#  '71',
#  '32%',
#  '61%',
#  '0.63',
#  '70',
#  '31%',
#  '60%',
#  '0.70',
#  '66',
#  '33%',
#  '58%',
#  '0.68',
#  '68',
#  '29%',
#  '56%',
#  '0.59',
#  '95',
#  '20%',
#  '62%',
#  '0.59',
#  '66',
#  '27%',
#  '55%',
#  '0.63',
#  '62',
#  '29%',
#  '60%',
#  '0.58',
#  '77',
#  '22%',
#  '57%',
#  '0.58',
#  '59',
#  '29%',
#  '68%',
#  '0.47',
#  '89',
#  '19%',
#  '49%',
#  '0.99',
#  '54',
#  '30%',
#  '52%',
#  '0.61',
#  '74',
#  '20%',
#  '54%',
#  '0.62',
#  '81',
#  '17%',
#  '59%',
#  '0.52',
#  '57',
#  '25%',
#  '54%',
#  '0.42',
#  '70',
#  '19%',
#  '44%',
#  '0.38',
#  '66',
#  '20%',
#  '48%',
#  '0.45',
#  '70',
#  '19%',
#  '54%',
#  '0.40',
#  '62',
#  '18%',
#  '61%',
#  '0.51',
#  '51',
#  '22%',
#  '63%',
#  '0.34',
#  '56',
#  '20%',
#  '63%',
#  '0.48',
#  '44',
#  '23%',
#  '59%',
#  '0.51',
#  '54',
#  '19%',
#  '57%',
#  '0.33',
#  '65',
#  '15%',
#  '58%',
#  '0.40',
#  '32',
#  '31%',
#  '72%',
#  '0.69',
#  '32',
#  '31%',
#  '63%']

# %%
[x.text for x in soup.find("tbody", "gel-long-primer").find_all("td", "gs-o-table__cell gs-o-table__cell--right")]
#soup.find("tbody","gel-long-primer").find("tr").
#    find("td", "gs-o-table__cell gs-o-table__cell--left").
#    find("div").find("div","sp-c-top-scorers__player-name gel-long-primer-bold").
#    find("span", "sp-c-abbreviation-switcher").find("span", "gs-u-vh gs-u-display-inherit@m").text
# Out:
# ['1',
#  '23',
#  '5',
#  '35',
#  '132',
#  '2',
#  '22',
#  '3',
#  '36',
#  '143',
#  '2',
#  '22',
#  '2',
#  '38',
#  '128',
#  '4',
#  '20',
#  '1',
#  '33',
#  '133',
#  '5',
#  '19',
#  '10',
#  '34',
#  '152',
#  '6',
#  '18',
#  '7',
#  '35',
#  '153',
#  '6',
#  '18',
#  '2',
#  '29',
#  '144',
#  '8',
#  '17',
#  '7',
#  '31',
#  '156',
#  '8',
#  '17',
#  '6',
#  '32',
#  '155',
#  '8',
#  '17',
#  '6',
#  '38',
#  '191',
#  '11',
#  '16',
#  '3',
#  '24',
#  '91',
#  '12',
#  '15',
#  '3',
#  '34',
#  '148',
#  '13',
#  '14',
#  '7',
#  '34',
#  '145',
#  '13',
#  '14',
#  '1',
#  '32',
#  '175',
#  '15',
#  '13',
#  '20',
#  '35',
#  '215',
#  '15',
#  '13',
#  '3',
#  '36',
#  '237',
#  '15',
#  '13',
#  '1',
#  '36',
#  '202',
#  '18',
#  '11',
#  '10',
#  '30',
#  '226',
#  '18',
#  '11',
#  '9',
#  '33',
#  '176',
#  '18',
#  '11',
#  '3',
#  '36',
#  '263',
#  '21',
#  '10',
#  '4',
#  '30',
#  '188',
#  '21',
#  '10',
#  '3',
#  '24',
#  '177',
#  '21',
#  '10',
# ...

# %%
#[x.text for x in all_body.find_all("tr")]

# %%
#names = soup.find("tbody","gel-long-primer").find("tr").find("td", "gs-o-table__cell gs-o-table__cell--left").find("div").find("div","sp-c-top-scorers__player-name gel-long-primer-bold").find("span", "sp-c-abbreviation-switcher").find("span", "gs-u-vh gs-u-display-inherit@m").text

# %%
url1 = "https://www.topuniversities.com/university-rankings/world-university-rankings/2020"

# %%
response1 = requests.get(url)

# %%
soup1 = BeautifulSoup(response1.content, "html.parser")

# %%
soup1
# Out:
# <!DOCTYPE html>
#
# <html class="b-reith-sans-font" lang="en-GB">
# <head>
# <script>window.Morph = {}</script>
# <script type="text/javascript">Morph.markPerformance = function(label) { if(window.performance && window.performance.mark) { window.performance.mark(label); } }; Morph.versions = {}; Morph.modules = {}; Morph.config = { cdn: "m.files.bbci.co.uk", pushEnv: "live" }; Morph.styles = {}; Morph.styleSrc = []; Morph.toInit = {bundles: [], registers: [], payloads: []};   Morph.initStyles = function() { if (!Morph.enhanced) { var eles = Array.prototype.slice.call(document.getElementsByTagName('noscript')); for (var i = 0, len = eles.length; i<len; i++) { if (eles[i].className === 'morph-core-style') { document.write(eles[i].innerText); eles[i].parentNode.removeChild(eles[i]); } } return; } for (var j = 0, jLen = Morph.styleSrc.length; j<jLen; j++) { document.write(Morph.styleSrc[j]); } Morph.styleSrc = []; };</script>
# ...

# %%
soup1.find("div", "site_contents")

# %%
soup1.body.find("div", "fixedContainer fixed")
